# %% [markdown]
# ## Choose the collections you want to compare
#
#
# This notebook allows the user to select multiple data tables, and combine them into one table for processing.

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
import ipywidgets as widgets
from IPython.display import display
from operator import itemgetter

import matplotlib

os.makedirs('../data/Combined', exist_ok=True)

# %% [markdown]
# Create a dropdown that allows multiple selection using command or click with the mouse or arrow keys to select additional individual data tables, or shift with the mouse to select each choice between the two clicked.

# %%
#Creates a list of all the paths to evaluated collection data.
EvaluatedMetadata=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith('Evaluated.csv.gz')]:
        EvaluatedMetadata.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w1=widgets.SelectMultiple(
    options=sorted(EvaluatedMetadata),
    value=['../data/Sample/Sample_Sample_Evaluated.csv.gz'],
    #rows=10,
    description='Evaluated Data',
    disabled=False
)
#Show the widget
display(w1)

#Creates a list of all the paths to evaluated collection data.
QuickE=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith('QuickE.csv')]:
        QuickE.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w2=widgets.SelectMultiple(
    options=sorted(QuickE),
    value=['../data/Sample/Sample_Sample_QuickE.csv'],
    #rows=10,
    description='QuickE Data',
    disabled=False
)
#Show the widget
display(w2)

#Creates a list of all the paths to evaluated collection data.
EvaluatedMetadata=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith('Occurance.csv')]:
        EvaluatedMetadata.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w3=widgets.SelectMultiple(
    options=sorted(EvaluatedMetadata),
    value=['../data/Sample/Sample_Sample_Occurance.csv'],
    #rows=10,
    description='Occurance Data',
    disabled=False
)
#Show the widget
display(w3)

#widget for naming the file
w4=widgets.Text(
    value='',
    placeholder='Your file name (no spaces)',
    description='Name your File:',
    disabled=False
)
display(w4)

# %% [markdown]
# Concatenate the files into one and save it in the combine directory

# %%
tupleList=[w1.value,w2.value,w3.value]
CollectionComparisons=max(tupleList,key=len)
DataDestination=os.path.join('../data/Combined', str(w4.value)+'.csv.gz')
CombinedDF = pd.concat((pd.read_csv(f) for f in CollectionComparisons)) 
CombinedDF.to_csv(DataDestination, mode = 'w', compression='gzip', index=False)
CombinedPivotDF = CombinedDF.pivot(index='Concept', columns='Collection', values='ConceptCount')
pd.options.display.float_format = '{:,.0f}'.format
ConceptCountsDF=CombinedPivotDF.fillna(0)
ConceptCountsDF.columns.names = ['']
ConceptCountsDF=ConceptCountsDF.reset_index()
ConceptCountsDF
# Out:
#                                        Concept  2006_EML  2007_EML  2008_EML  \
# 0                                     Abstract       250       235       250
# 1                        Attribute Constraints        10        63         8
# 2                         Attribute Definition     3,456     5,019     2,867
# 3                               Attribute List       351       315       212
# 4                                       Author       390       519       521
# 5                          Author / Originator       390       519       521
# 6            Author / Originator Email Address       104       236       257
# 7               Author / Originator Identifier        90       137       163
# 8          Author / Originator Identifier Type         0         0         0
# 9   Author / Originator World Wide Web Address       233       368       404
# 10                                Bounding Box       330       625       325
# 11                            Contributor Name       732       408       477
# 12                            Contributor Role       427       228       213
# 13                         Distribution Format       192       227       157
# 14                       Easternmost Longitude       318       623       321
# 15                                    End Time       209       238       248
# 16                      Entity Type Definition       238       299       216
# 17            Entity and Attribute Information       238       299       216
# 18                                  Instrument       190       125       277
# 19                                     Keyword     2,064     2,702     2,820
# 20                                Keyword Type       247       112       161
# 21                          Keyword Vocabulary       156       258       207
# 22                                 Maintenance       178       190       132
# 23                 Metadata Access Constraints       171       172       174
# 24                            Metadata Contact       178       192       151
# 25                      Metadata Modified Date        25        84        18
# 26                    Metadata Use Constraints       171       172       174
# 27                       Northernmost Latitude       328       624       315
# 28                           Number of Records       250       250       250
# 29                           Organization Name       864       809       819
# ..                                         ...       ...       ...       ...
# 47                       Resource Distribution       242       240       241
# 48                             Resource Format       192       227       157
# 49                         Resource Identifier       250       250       250
# 50                    Resource Identifier Type       250       250       250
# 51                           Resource Language        51        42        40
# 52                            Resource Lineage       203       209       163
# 53                          Resource Long Name       250       250       250
# 54                Resource Quality Description        52        28        68
# 55                      Resource Revision Date        25        84        18
# 56                             Resource Status       171       172       174
# 57                              Resource Title       250       250       250
# 58                   Resource Update Frequency         7        16         5
# 59                    Resource Use Constraints       250       248       225
# 60                       Resource on-line Link       232       240       241
# 61                Responsible Party Identifier         0        32         0
# 62           Responsible Party Identifier Type         0         2         0
# 63                                      Rights       250       248       225
# 64                        Security Constraints       171       172       174
# 65                       Southernmost Latitude       321       623       323
# 66                              Spatial Extent       337       644       329
# 67                                  Start Time       209       236       248
# 68                    Supplemental Information        73         9        13
# 69                            Taxonomic Extent        12        45        23
# 70                             Temporal Extent       252       247       250
# 71                            Temporal Keyword         0        10         8
# 72                                     Unknown    49,666    64,093    50,081
# 73                            Vertical Maximum       105        29        29
# 74                            Vertical Minimum       105        39        29
# 75                         Vertical Resolution       100        20        17
# 76                       Westernmost Longitude       322       624       313
#
#     2009_EML  2010_EML  2011_EML  2012_EML  2013_EML  2014_EML  2015_EML  \
# 0        247       244       241       244       250       249       250
# 1          0         0         7         7         0       112         0
# 2      4,405     2,068     3,189     3,064     2,916     6,009     2,078
# 3        350       164       250       255       238       233       150
# 4        535       392       441       370       387       473       636
# 5        535       392       441       370       387       473       636
# 6        109       136        39        75       107       146       237
# 7        285       215        25       114       199       184       136
# 8          0         0         1         5         1         0         0
# 9        404       173       240       189       177       302       298
# 10       726       677       368       370     1,158       382       265
# 11       350       197       311       264       647       321        67
# 12       225       115       133       161       347       182        40
# 13       206       129       162       219       224       150       130
# 14       724       676       362       370     1,146       382       264
# 15       224       201       198       243       223       237       128
# 16       355       127       216       185       235       281       153
# 17       355       127       216       185       235       281       153
# 18       309        76        94        63       229       142        54
# 19     2,529     1,852     4,166     4,233     2,887     2,693     2,927
# 20       153       205       240       215        80       238       440
# 21       469        73       466       240       166       279        74
# 22       108        86       166       101       214       222       140
# 23       201       182       229       230       250       250       250
# 24       113       115        80       203       221       227       443
# 25         5         0         0         2        61        53         1
# 26       201       182       229       230       250       250       250
# 27       676       675       363       370     1,134       380       262
# 28       250       250       250       250       250       250       250
# 29       731       595       690       709     1,031       863     1,671
# ..       ...       ...       ...       ...       ...       ...       ...
# 47       238       206       226       133       240       225        38
# 48       206       129       162       219       224       150       130
# 49       250       250       250       250       250       250       250
# 50       250       250       250       250       250       250       250
# 51        99         6       156        43        21        37       127
# 52       213       129       202       220       244       198       249
# 53       250       250       250       250       250       250       250
# 54        20        12        50        22        73        34        10
# 55         5         0         0         2        61        53         1
# 56       201       182       229       230       250       250       250
# 57       250       250       250       250       250       250       250
# 58        13         0        84        20         4        85       121
# 59       238       176       241       156       250       248       249
# 60       238       206       225       133       240       222        38
# 61       106         8         6        10         2         8         0
# 62         0         0         0         3         0         0         0
# 63       238       176       241       156       250       248       249
# 64       201       182       229       230       250       250       250
# 65       661       676       361       370     1,138       382       263
# 66       729       687       371       370     1,167       383       265
# 67       224       201       198       243       223       237       128
# 68         8         2        52         9        13        71         2
# 69        33        12        10        50        34        37        10
# 70       224       201       229       248       247       255       249
# 71         0         1         7         4         1         4         2
# 72    57,819    35,251    56,572    45,537    57,883    69,072    53,448
# 73       366        45       142        21        11        31        18
# 74       366        45       142        21        11        31        18
# 75       104        45        41        20        10        15        10
# 76       724       674       361       369     1,140       377       264
#
#     2016_EML
# 0        250
# 1         42
# 2      5,594
# 3        415
# 4        462
# 5        462
# 6         91
# 7         75
# 8          0
# 9        271
# 10       667
# 11       468
# 12       233
# 13       246
# 14       614
# 15       224
# 16       408
# 17       408
# 18        65
# 19     2,433
# 20       123
# 21       377
# 22       152
# 23       250
# 24       145
# 25        56
# 26       250
# 27       655
# 28       250
# 29       896
# ..       ...
# 47       237
# 48       246
# 49       250
# 50       250
# 51       137
# 52       232
# 53       250
# 54        27
# 55        56
# 56       250
# 57       250
# 58        15
# 59       243
# 60       237
# 61        10
# 62         0
# 63       243
# 64       250
# 65       656
# 66       669
# 67       224
# 68        49
# 69        19
# 70       228
# 71         3
# 72    58,200
# 73       260
# 74       262
# 75       121
# 76       614
#
# [77 rows x 12 columns]

# %%
CombinedPivotDF = CombinedDF.pivot(index='Concept', columns='Collection', values='ConceptCount')
pd.options.display.float_format = '{:,.0f}'.format
ConceptCountsDF=CombinedPivotDF.fillna(0)
ConceptCountsDF.columns.names = ['']
ConceptCountsDF=ConceptCountsDF.reset_index()
ConceptCountsDF
# Out:
#                                        Concept  2006_EML  2007_EML  2008_EML  \
# 0                                     Abstract       250       235       250
# 1                        Attribute Constraints        10        63         8
# 2                         Attribute Definition     3,456     5,019     2,867
# 3                               Attribute List       351       315       212
# 4                                       Author       390       519       521
# 5                          Author / Originator       390       519       521
# 6            Author / Originator Email Address       104       236       257
# 7               Author / Originator Identifier        90       137       163
# 8          Author / Originator Identifier Type         0         0         0
# 9   Author / Originator World Wide Web Address       233       368       404
# 10                                Bounding Box       330       625       325
# 11                            Contributor Name       732       408       477
# 12                            Contributor Role       427       228       213
# 13                         Distribution Format       192       227       157
# 14                       Easternmost Longitude       318       623       321
# 15                                    End Time       209       238       248
# 16                      Entity Type Definition       238       299       216
# 17            Entity and Attribute Information       238       299       216
# 18                                  Instrument       190       125       277
# 19                                     Keyword     2,064     2,702     2,820
# 20                                Keyword Type       247       112       161
# 21                          Keyword Vocabulary       156       258       207
# 22                                 Maintenance       178       190       132
# 23                 Metadata Access Constraints       171       172       174
# 24                            Metadata Contact       178       192       151
# 25                      Metadata Modified Date        25        84        18
# 26                    Metadata Use Constraints       171       172       174
# 27                       Northernmost Latitude       328       624       315
# 28                           Number of Records       250       250       250
# 29                           Organization Name       864       809       819
# ..                                         ...       ...       ...       ...
# 47                       Resource Distribution       242       240       241
# 48                             Resource Format       192       227       157
# 49                         Resource Identifier       250       250       250
# 50                    Resource Identifier Type       250       250       250
# 51                           Resource Language        51        42        40
# 52                            Resource Lineage       203       209       163
# 53                          Resource Long Name       250       250       250
# 54                Resource Quality Description        52        28        68
# 55                      Resource Revision Date        25        84        18
# 56                             Resource Status       171       172       174
# 57                              Resource Title       250       250       250
# 58                   Resource Update Frequency         7        16         5
# 59                    Resource Use Constraints       250       248       225
# 60                       Resource on-line Link       232       240       241
# 61                Responsible Party Identifier         0        32         0
# 62           Responsible Party Identifier Type         0         2         0
# 63                                      Rights       250       248       225
# 64                        Security Constraints       171       172       174
# 65                       Southernmost Latitude       321       623       323
# 66                              Spatial Extent       337       644       329
# 67                                  Start Time       209       236       248
# 68                    Supplemental Information        73         9        13
# 69                            Taxonomic Extent        12        45        23
# 70                             Temporal Extent       252       247       250
# 71                            Temporal Keyword         0        10         8
# 72                                     Unknown    49,666    64,093    50,081
# 73                            Vertical Maximum       105        29        29
# 74                            Vertical Minimum       105        39        29
# 75                         Vertical Resolution       100        20        17
# 76                       Westernmost Longitude       322       624       313
#
#     2009_EML  2010_EML  2011_EML  2012_EML  2013_EML  2014_EML  2015_EML  \
# 0        247       244       241       244       250       249       250
# 1          0         0         7         7         0       112         0
# 2      4,405     2,068     3,189     3,064     2,916     6,009     2,078
# 3        350       164       250       255       238       233       150
# 4        535       392       441       370       387       473       636
# 5        535       392       441       370       387       473       636
# 6        109       136        39        75       107       146       237
# 7        285       215        25       114       199       184       136
# 8          0         0         1         5         1         0         0
# 9        404       173       240       189       177       302       298
# 10       726       677       368       370     1,158       382       265
# 11       350       197       311       264       647       321        67
# 12       225       115       133       161       347       182        40
# 13       206       129       162       219       224       150       130
# 14       724       676       362       370     1,146       382       264
# 15       224       201       198       243       223       237       128
# 16       355       127       216       185       235       281       153
# 17       355       127       216       185       235       281       153
# 18       309        76        94        63       229       142        54
# 19     2,529     1,852     4,166     4,233     2,887     2,693     2,927
# 20       153       205       240       215        80       238       440
# 21       469        73       466       240       166       279        74
# 22       108        86       166       101       214       222       140
# 23       201       182       229       230       250       250       250
# 24       113       115        80       203       221       227       443
# 25         5         0         0         2        61        53         1
# 26       201       182       229       230       250       250       250
# 27       676       675       363       370     1,134       380       262
# 28       250       250       250       250       250       250       250
# 29       731       595       690       709     1,031       863     1,671
# ..       ...       ...       ...       ...       ...       ...       ...
# 47       238       206       226       133       240       225        38
# 48       206       129       162       219       224       150       130
# 49       250       250       250       250       250       250       250
# 50       250       250       250       250       250       250       250
# 51        99         6       156        43        21        37       127
# 52       213       129       202       220       244       198       249
# 53       250       250       250       250       250       250       250
# 54        20        12        50        22        73        34        10
# 55         5         0         0         2        61        53         1
# 56       201       182       229       230       250       250       250
# 57       250       250       250       250       250       250       250
# 58        13         0        84        20         4        85       121
# 59       238       176       241       156       250       248       249
# 60       238       206       225       133       240       222        38
# 61       106         8         6        10         2         8         0
# 62         0         0         0         3         0         0         0
# 63       238       176       241       156       250       248       249
# 64       201       182       229       230       250       250       250
# 65       661       676       361       370     1,138       382       263
# 66       729       687       371       370     1,167       383       265
# 67       224       201       198       243       223       237       128
# 68         8         2        52         9        13        71         2
# 69        33        12        10        50        34        37        10
# 70       224       201       229       248       247       255       249
# 71         0         1         7         4         1         4         2
# 72    57,819    35,251    56,572    45,537    57,883    69,072    53,448
# 73       366        45       142        21        11        31        18
# 74       366        45       142        21        11        31        18
# 75       104        45        41        20        10        15        10
# 76       724       674       361       369     1,140       377       264
#
#     2016_EML
# 0        250
# 1         42
# 2      5,594
# 3        415
# 4        462
# 5        462
# 6         91
# 7         75
# 8          0
# 9        271
# 10       667
# 11       468
# 12       233
# 13       246
# 14       614
# 15       224
# 16       408
# 17       408
# 18        65
# 19     2,433
# 20       123
# 21       377
# 22       152
# 23       250
# 24       145
# 25        56
# 26       250
# 27       655
# 28       250
# 29       896
# ..       ...
# 47       237
# 48       246
# 49       250
# 50       250
# 51       137
# 52       232
# 53       250
# 54        27
# 55        56
# 56       250
# 57       250
# 58        15
# 59       243
# 60       237
# 61        10
# 62         0
# 63       243
# 64       250
# 65       656
# 66       669
# 67       224
# 68        49
# 69        19
# 70       228
# 71         3
# 72    58,200
# 73       260
# 74       262
# 75       121
# 76       614
#
# [77 rows x 12 columns]

# %%
CombinedPivotDF = CombinedDF.pivot(index='Concept', columns='Collection', values='AverageOccurancePerRecord')
pd.options.display.float_format = '{:,.2f}'.format
RecordCountsDF=CombinedPivotDF.fillna(0)
RecordCountsDF.columns.names = ['']
RecordCountsDF.reset_index()
# Out:
#                                        Concept  2006_EML  2007_EML  2008_EML  \
# 0                                     Abstract      1.00      0.94      1.00
# 1                        Attribute Constraints      0.04      0.25      0.03
# 2                         Attribute Definition     13.82     20.08     11.47
# 3                               Attribute List      1.40      1.26      0.85
# 4                                       Author      1.56      2.08      2.08
# 5                          Author / Originator      1.56      2.08      2.08
# 6            Author / Originator Email Address      0.42      0.94      1.03
# 7               Author / Originator Identifier      0.36      0.55      0.65
# 8          Author / Originator Identifier Type      0.00      0.00      0.00
# 9   Author / Originator World Wide Web Address      0.93      1.47      1.62
# 10                                Bounding Box      1.32      2.50      1.30
# 11                            Contributor Name      2.93      1.63      1.91
# 12                            Contributor Role      1.71      0.91      0.85
# 13                         Distribution Format      0.77      0.91      0.63
# 14                       Easternmost Longitude      1.27      2.49      1.28
# 15                                    End Time      0.84      0.95      0.99
# 16                      Entity Type Definition      0.95      1.20      0.86
# 17            Entity and Attribute Information      0.95      1.20      0.86
# 18                                  Instrument      0.76      0.50      1.11
# 19                                     Keyword      8.26     10.81     11.28
# 20                                Keyword Type      0.99      0.45      0.64
# 21                          Keyword Vocabulary      0.62      1.03      0.83
# 22                                 Maintenance      0.71      0.76      0.53
# 23                 Metadata Access Constraints      0.68      0.69      0.70
# 24                            Metadata Contact      0.71      0.77      0.60
# 25                      Metadata Modified Date      0.10      0.34      0.07
# 26                    Metadata Use Constraints      0.68      0.69      0.70
# 27                       Northernmost Latitude      1.31      2.50      1.26
# 28                           Number of Records      1.00      1.00      1.00
# 29                           Organization Name      3.46      3.24      3.28
# ..                                         ...       ...       ...       ...
# 47                       Resource Distribution      0.97      0.96      0.96
