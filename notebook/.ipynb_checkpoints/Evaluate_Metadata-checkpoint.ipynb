# %% [markdown]
# ### This notebook allows the user to create a directory structure and locally upload the metadata to the Metadata Evaluation repository.

# %%
import pandas as pd
import os
from os import walk
import shutil
from ipywidgets import *
import ipywidgets as widgets
import requests
import io
from IPython.display import display
import metadataEvaluation

# %% [markdown]
# ### Now let's select some metadata.

# %%
#functions to identify and label an xml collection for Metadata Evaluation
def OrganizationChoices(organization):
    
    metadataEvaluation.Organization=organization
    print("Curating Organization", metadataEvaluation.Organization)
    
def CollectionName(collection):
    metadataEvaluation.Collection=collection
    print("Collection is named", metadataEvaluation.Collection)
    
def DialectName(dialect):
    metadataEvaluation.Dialect=dialect
    print("Collection is written in the", metadataEvaluation.Dialect,"dialect")   
    
def metadataLocation(directory):
    metadataEvaluation.MetadataLocation=directory
    print("The local directory", metadataEvaluation.MetadataLocation,"contains the metadata for evaluation")    
    
#Create a function to select the organization the metadata comes from
    
def DataProductChoices(dataProduct):
    global sEvaluatedMetadataDF
    DataDirectory = "../data/"+metadataEvaluation.Organization
    filePath=DataDirectory+'/'+dataProduct
    sEvaluatedMetadataDF= pd.read_csv(os.path.join(filePath))
    return sEvaluatedMetadataDF       
    
w=interactive(OrganizationChoices, organization='')    
w2=interactive(CollectionName, collection='')
w3=interactive(DialectName, dialect='')
w4=interactive(metadataLocation, directory='')    

display(w)
display(w2)
display(w3)
display(w4)

# %% [markdown]
# Evaluate the collection

# %%
# %cd ../zip
MetadataDestination=os.path.join(metadataEvaluation.Organization,metadataEvaluation.Collection,metadataEvaluation.Dialect,'xml')
os.makedirs(MetadataDestination, exist_ok=True)
os.makedirs(os.path.join('../data',metadataEvaluation.Organization), exist_ok=True)
src_files = os.listdir(metadataEvaluation.MetadataLocation)
for file_name in src_files:
    full_file_name = os.path.join(metadataEvaluation.MetadataLocation, file_name)
    if (os.path.isfile(full_file_name)):
        shutil.copy(full_file_name, MetadataDestination)
shutil.make_archive('../upload/metadata', 'zip', os.getcwd())

# %cd ../upload 
# Send metadata package, read the response into a dataframe
url = 'http://metadig.nceas.ucsb.edu/metadata/evaluator'
files = {'zipxml': open('metadata.zip', 'rb')}
r = requests.post(url, files=files, headers={"Accept-Encoding": "gzip"})
r.raise_for_status()
EvaluatedMetadataDF = pd.read_csv(io.StringIO(r.text), quotechar='"')

#Change directories, delete upload directory and zip. Delete copied metadata.
# %cd ../
shutil.rmtree('upload')
# %cd zip
shutil.rmtree(metadataEvaluation.Organization)
# %cd ../data

metadataEvaluation.dataProducts(EvaluatedMetadataDF)

#Create a list of subdirectories in the collection directory of MILE2 to select metadata for evaluation
DataDirectory = "../data/"+metadataEvaluation.Organization
DataProducts = os.listdir(DataDirectory)

 
#organization selector dropdown    
interactive(DataProductChoices,dataProduct=sorted(DataProducts))
# Out:
# /Users/scgordon/MetadataEvaluation/zip
# /Users/scgordon/MetadataEvaluation/upload
# /Users/scgordon/MetadataEvaluation
# /Users/scgordon/MetadataEvaluation/zip
# /Users/scgordon/MetadataEvaluation/data
# No elements contain a variant of 'Not provided' in their content for this collection
# Data products created for the 2010 collection from the LTER organization

# %%
sEvaluatedMetadataDF
# Out:
#                                                  XPath Collection  XPathCount  \
# 0                                    Number of Records   2010_EML         100
# 1                                      /eml/@packageId   2010_EML         100
# 2                                 /eml/@schemaLocation   2010_EML         100
# 3                                          /eml/@scope   2010_EML          42
# 4                                         /eml/@system   2010_EML         100
# 5                                          /eml/access   2010_EML         385
# 6                              /eml/access/@authSystem   2010_EML          77
# 7                                   /eml/access/@order   2010_EML          77
# 8                                   /eml/access/@scope   2010_EML          74
# 9                                  /eml/access/@system   2010_EML          31
# 10                        /eml/access/allow/permission   2010_EML         154
# 11                         /eml/access/allow/principal   2010_EML         154
# 12   /eml/additionalMetadata/additionalDataset/Data...   2010_EML           3
# 13   /eml/additionalMetadata/additionalDataset/LTER...   2010_EML           3
# 14   /eml/additionalMetadata/additionalDataset/addD...   2010_EML           4
# 15   /eml/additionalMetadata/additionalDataset/data...   2010_EML           3
# 16   /eml/additionalMetadata/additionalDataset/data...   2010_EML           1
# 17   /eml/additionalMetadata/additionalDataset/data...   2010_EML           1
# 18   /eml/additionalMetadata/additionalDataset/data...   2010_EML           2
# 19   /eml/additionalMetadata/additionalDataset/proj...   2010_EML           4
# 20   /eml/additionalMetadata/additionalDataset/proj...   2010_EML           3
# 21   /eml/additionalMetadata/additionalDataset/rese...   2010_EML           4
# 22   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          15
# 23   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML           5
# 24   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          22
# 25   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          21
# 26   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          61
# 27   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          25
# 28   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          61
# 29   /eml/additionalMetadata/metadata/ns2:unitList/...   2010_EML          14
# ..                                                 ...        ...         ...
# 470  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          19
# 471  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          19
# 472  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          19
# 473  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          23
# 474  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          23
# 475  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          23
# 476  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          23
# 477  /eml/dataset/project/studyAreaDescription/cove...   2010_EML          23
# 478  /eml/dataset/project/studyAreaDescription/cove...   2010_EML           4
# 479  /eml/dataset/project/studyAreaDescription/cove...   2010_EML           4
# 480  /eml/dataset/project/studyAreaDescription/cove...   2010_EML           4
# 481                         /eml/dataset/project/title   2010_EML          30
# 482                               /eml/dataset/pubDate   2010_EML         194
# 483                              /eml/dataset/pubPlace   2010_EML          11
# 484                             /eml/dataset/publisher   2010_EML          55
# 485                      /eml/dataset/publisher/@scope   2010_EML          13
# 486              /eml/dataset/publisher/address/@scope   2010_EML          11
# 487  /eml/dataset/publisher/address/administrativeArea   2010_EML          46
# 488                /eml/dataset/publisher/address/city   2010_EML          46
# 489             /eml/dataset/publisher/address/country   2010_EML          35
# 490       /eml/dataset/publisher/address/deliveryPoint   2010_EML         138
# 491          /eml/dataset/publisher/address/postalCode   2010_EML          46
# 492       /eml/dataset/publisher/electronicMailAddress   2010_EML          48
# 493                   /eml/dataset/publisher/onlineUrl   2010_EML          25
# 494            /eml/dataset/publisher/organizationName   2010_EML          54
# 495                       /eml/dataset/publisher/phone   2010_EML          47
# 496            /eml/dataset/publisher/phone/@phonetype   2010_EML          47
# 497                  /eml/dataset/publisher/references   2010_EML           1
# 498                             /eml/dataset/shortName   2010_EML          30
# 499                                 /eml/dataset/title   2010_EML         200
#
#      RecordCount  AverageOccurrencePerRecord CollectionOccurrence%
# 0            100                           1               100.00%
# 1            100                           1               100.00%
# 2            100                           1               100.00%
# 3             42                           0                42.00%
# 4            100                           1               100.00%
# 5             77                           4                77.00%
# 6             77                           1                77.00%
# 7             77                           1                77.00%
# 8             74                           1                74.00%
# 9             31                           0                31.00%
# 10            77                           2                77.00%
# 11            77                           2                77.00%
# 12             3                           0                 3.00%
# 13             3                           0                 3.00%
# 14             4                           0                 4.00%
# 15             3                           0                 3.00%
# 16             1                           0                 1.00%
# 17             1                           0                 1.00%
# 18             2                           0                 2.00%
# 19             4                           0                 4.00%
# 20             3                           0                 3.00%
# 21             4                           0                 4.00%
# 22            15                           0                15.00%
# 23             5                           0                 5.00%
# 24             5                           0                 5.00%
# 25            17                           0                17.00%
# 26            21                           1                21.00%
# 27            18                           0                18.00%
# 28            21                           1                21.00%
# 29             4                           0                 4.00%
# ..           ...                         ...                   ...
# 470           19                           0                19.00%
# 471           19                           0                19.00%
# 472           19                           0                19.00%
# 473           23                           0                23.00%
# 474           23                           0                23.00%
# 475           23                           0                23.00%
# 476           23                           0                23.00%
# 477           23                           0                23.00%
# 478            4                           0                 4.00%
# 479            4                           0                 4.00%
# 480            4                           0                 4.00%
# 481           30                           0                30.00%
# 482           97                           2                97.00%
# 483           11                           0                11.00%
# 484           55                           1                55.00%
# 485           13                           0                13.00%
# 486           11                           0                11.00%
# 487           46                           0                46.00%
# 488           46                           0                46.00%
# 489           35                           0                35.00%
# 490           46                           1                46.00%
# 491           46                           0                46.00%
# 492           24                           0                24.00%
# 493           25                           0                25.00%
# 494           54                           1                54.00%
# 495           35                           0                35.00%
# 496           35                           0                35.00%
# 497            1                           0                 1.00%
# 498           30                           0                30.00%
# 499          100                           2               100.00%
#
# [500 rows x 6 columns]

# %% [markdown]
# ### Combine different types of evaluated data to compare between collections or observe trends over time
#
# * [Combine_Data](Combine_Data.ipynb)
