# %% [markdown]
# ## Choose the collections you want to compare
#
#
# This notebook allows the user to select multiple data tables, and combine them into one table for processing.

# %%
import pandas as pd
pd.options.display.max_colwidth=200
import os
from os import walk
import ipywidgets as widgets
from IPython.display import display
from operator import itemgetter
import metadataEvaluation
os.makedirs('../data/Combined', exist_ok=True)

# %% [markdown]
# Create a dropdown that allows multiple selection using command or click with the mouse or arrow keys to select additional individual data tables, or shift with the mouse to select each choice between the two clicked.

# %%
#Creates a list of all the paths to evaluated collection data.
EvaluatedMetadata=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith('Evaluated.csv.gz')]:
        EvaluatedMetadata.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w1=widgets.SelectMultiple(
    options=sorted(EvaluatedMetadata),
    value=['../data/Sample/Sample_Sample_Evaluated.csv.gz'],
    #rows=10,
    description='Evaluated Data',
    disabled=False
)
#Show the widget
display(w1)

#Creates a list of all the paths to evaluated collection data.
QuickE=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith('QuickE.csv')]:
        QuickE.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w2=widgets.SelectMultiple(
    options=sorted(QuickE),
    value=['../data/Sample/Sample_Sample_QuickE.csv'],
    #rows=10,
    description='QuickE Data',
    disabled=False
)
#Show the widget
display(w2)

#Creates a list of all the paths to evaluated collection data.
Occurrence=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if f.endswith('Occurrence.csv')]:
        Occurrence.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w3=widgets.SelectMultiple(
    options=sorted(Occurrence),
    value=['../data/Sample/Sample_Sample_Occurrence.csv'],
    #rows=10,
    description='Occurrence Data',
    disabled=False
)
#Show the widget
display(w3)

#widget for naming the file
w4=widgets.Text(
    value='',
    placeholder='Your file name (no spaces)',
    description='Name your File:',
    disabled=False
)
display(w4)

# %% [markdown]
# Concatenate the files into one and save it in the combine directory

# %%
tupleList=[w1.value,w2.value,w3.value]
metadataEvaluation.CollectionComparisons=max(tupleList,key=len)
metadataEvaluation.DataDestination=os.path.join('../data/Combined', str(w4.value)+'.csv')

# %%
metadataEvaluation.CombineConceptOccurrence(metadataEvaluation.CollectionComparisons)
# Out:
#                                        Concept 2008_EML 2009_EML 2010_EML
# 0                                     Abstract  100.00%  100.00%   98.00%
# 1                        Attribute Constraints    1.00%        0        0
# 2                         Attribute Definition   69.00%   86.00%   54.00%
# 3                               Attribute List   69.00%   86.00%   54.00%
# 4                                       Author  100.00%  100.00%  100.00%
# 5                          Author / Originator  100.00%  100.00%  100.00%
# 6            Author / Originator Email Address   71.00%   25.00%   46.00%
# 7               Author / Originator Identifier   38.00%   44.00%   55.00%
# 8   Author / Originator World Wide Web Address   94.00%   75.00%   53.00%
# 9                                 Bounding Box   94.00%  100.00%   97.00%
# 10                            Contributor Name   35.00%   46.00%   36.00%
# 11                            Contributor Role   35.00%   46.00%   36.00%
# 12                         Distribution Format   61.00%   86.00%   52.00%
# 13                       Easternmost Longitude   94.00%  100.00%   97.00%
# 14                                    End Time   99.00%   88.00%   86.00%
# 15                      Entity Type Definition   68.00%   84.00%   38.00%
# 16            Entity and Attribute Information   68.00%   84.00%   38.00%
# 17                                  Instrument   26.00%   25.00%    6.00%
# 18                                     Keyword   94.00%  100.00%   97.00%
# 19                                Keyword Type   43.00%   45.00%   61.00%
# 20                          Keyword Vocabulary   38.00%   70.00%   18.00%
# 21                                 Maintenance   54.00%   39.00%   36.00%
# 22                 Metadata Access Constraints   71.00%   78.00%   77.00%
# 23                            Metadata Contact   61.00%   43.00%   49.00%
# 24                      Metadata Modified Date    1.00%    1.00%        0
# 25                    Metadata Use Constraints   71.00%   78.00%   77.00%
# 26                       Northernmost Latitude   94.00%  100.00%   97.00%
# 27                           Number of Records  100.00%  100.00%  100.00%
# 28                           Organization Name   92.00%  100.00%  100.00%
# 29                    Originating Organization   84.00%   78.00%   66.00%
# ..                                         ...      ...      ...      ...
# 44             Resource Creation/Revision Date   91.00%   91.00%   97.00%
# 45                       Resource Distribution   96.00%   99.00%   82.00%
# 46                             Resource Format   61.00%   86.00%   52.00%
# 47                         Resource Identifier  100.00%  100.00%  100.00%
# 48                    Resource Identifier Type  100.00%  100.00%  100.00%
# 49                           Resource Language   19.00%   48.00%    3.00%
# 50                            Resource Lineage   62.00%   89.00%   53.00%
# 51                          Resource Long Name  100.00%  100.00%  100.00%
# 52                Resource Quality Description   26.00%    8.00%    4.00%
# 53                      Resource Revision Date    1.00%    1.00%        0
# 54                             Resource Status   71.00%   78.00%   77.00%
# 55                              Resource Title  100.00%  100.00%  100.00%
# 56                   Resource Update Frequency    3.00%    2.00%        0
# 57                    Resource Use Constraints   92.00%   94.00%   75.00%
# 58                       Resource on-line Link   96.00%   99.00%   82.00%
# 59                Responsible Party Identifier        0   17.00%    4.00%
# 60                                      Rights   92.00%   94.00%   75.00%
# 61                        Security Constraints   71.00%   78.00%   77.00%
# 62                       Southernmost Latitude   94.00%  100.00%   97.00%
# 63                              Spatial Extent   94.00%  100.00%   97.00%
# 64                                  Start Time   99.00%   88.00%   86.00%
# 65                    Supplemental Information    5.00%    2.00%    1.00%
# 66                            Taxonomic Extent    8.00%    8.00%    5.00%
# 67                             Temporal Extent  100.00%   88.00%   86.00%
# 68                            Temporal Keyword    3.00%        0    1.00%
# 69                                     Unknown  100.00%  100.00%  100.00%
# 70                            Vertical Maximum    6.00%   43.00%   12.00%
# 71                            Vertical Minimum    6.00%   43.00%   12.00%
# 72                         Vertical Resolution    6.00%   43.00%   12.00%
# 73                       Westernmost Longitude   94.00%  100.00%   97.00%
#
# [74 rows x 4 columns]

# %%
metadataEvaluation.recordConceptCounts(metadataEvaluation.CollectionComparisons)
# Out:
#                                        Concept  2008_EML  2009_EML  2010_EML
# 0                                     Abstract       100       100        98
# 1                        Attribute Constraints         1         0         0
# 2                         Attribute Definition        69        86        54
# 3                               Attribute List        69        86        54
# 4                                       Author       100       100       100
# 5                          Author / Originator       100       100       100
# 6            Author / Originator Email Address        71        25        46
# 7               Author / Originator Identifier        38        44        55
# 8   Author / Originator World Wide Web Address        94        75        53
# 9                                 Bounding Box        94       100        97
# 10                            Contributor Name        35        46        36
# 11                            Contributor Role        35        46        36
# 12                         Distribution Format        61        86        52
# 13                       Easternmost Longitude        94       100        97
# 14                                    End Time        99        88        86
# 15                      Entity Type Definition        68        84        38
# 16            Entity and Attribute Information        68        84        38
# 17                                  Instrument        26        25         6
# 18                                     Keyword        94       100        97
# 19                                Keyword Type        43        45        61
# 20                          Keyword Vocabulary        38        70        18
# 21                                 Maintenance        54        39        36
# 22                 Metadata Access Constraints        71        78        77
# 23                            Metadata Contact        61        43        49
# 24                      Metadata Modified Date         1         1         0
# 25                    Metadata Use Constraints        71        78        77
# 26                       Northernmost Latitude        94       100        97
# 27                           Number of Records       100       100       100
# 28                           Organization Name        92       100       100
# 29                    Originating Organization        84        78        66
# ..                                         ...       ...       ...       ...
# 44             Resource Creation/Revision Date        91        91        97
# 45                       Resource Distribution        96        99        82
# 46                             Resource Format        61        86        52
# 47                         Resource Identifier       100       100       100
# 48                    Resource Identifier Type       100       100       100
# 49                           Resource Language        19        48         3
# 50                            Resource Lineage        62        89        53
# 51                          Resource Long Name       100       100       100
# 52                Resource Quality Description        26         8         4
# 53                      Resource Revision Date         1         1         0
# 54                             Resource Status        71        78        77
# 55                              Resource Title       100       100       100
# 56                   Resource Update Frequency         3         2         0
# 57                    Resource Use Constraints        92        94        75
# 58                       Resource on-line Link        96        99        82
# 59                Responsible Party Identifier         0        17         4
# 60                                      Rights        92        94        75
# 61                        Security Constraints        71        78        77
# 62                       Southernmost Latitude        94       100        97
# 63                              Spatial Extent        94       100        97
# 64                                  Start Time        99        88        86
# 65                    Supplemental Information         5         2         1
# 66                            Taxonomic Extent         8         8         5
# 67                             Temporal Extent       100        88        86
# 68                            Temporal Keyword         3         0         1
# 69                                     Unknown       100       100       100
# 70                            Vertical Maximum         6        43        12
# 71                            Vertical Minimum         6        43        12
# 72                         Vertical Resolution         6        43        12
# 73                       Westernmost Longitude        94       100        97
#
# [74 rows x 4 columns]
